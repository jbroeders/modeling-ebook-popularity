# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
MAEs = [0.339, 0.300, 0.277, 0.262]
RMSEs = [0.431, 0.394, 0.369, 0.353]
x_labels = ['random', 'publish_year', 'sentimental features', 'all']

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
inputs = ['random', 'random', 'publish_year', 'publish_year', 'sentiment', 'sentiment', 'combined', 'combined']
metrics = ['MAE', 'RMSE', 'MAE', 'RMSE', 'MAE', 'RMSE', 'MAE', 'RMSE']
values = [0.339, 0.431, 0.300, 0.394, 0.277, 0.369, 0.262, 0.353]

# %%
df = pd.DataFrame()
df['inp'] = inputs
df['Metric'] = metrics
df['val'] = values

# %%
df
# Out:
#             inp Metric    val
# 0        random    MAE  0.339
# 1        random   RMSE  0.431
# 2  publish_year    MAE  0.300
# 3  publish_year   RMSE  0.394
# 4     sentiment    MAE  0.277
# 5     sentiment   RMSE  0.369
# 6      combined    MAE  0.262
# 7      combined   RMSE  0.353

# %%
ax = sns.catplot(
    data=df, kind="bar",
    x="inp", y="val", hue="Metric",
    ci="sd", alpha=.6, height=6
)

ax.despine(left=True)
ax.set_axis_labels("Input", "Error")
ax.legend.set_title("Metric")
ax.fig.suptitle('Random Forest performance')
plt.grid(axis='y')
